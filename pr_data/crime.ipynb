# %%
from base import exports
import logging
from pandasql import sqldf
import pandas as pd

log = logging.getLogger(__name__)
logging.basicConfig(level=logging.INFO)

# %% [markdown]
# ### Crime

# %%
df = exports.get_df_from_csv(file_name='data/mapa_del_crimen.csv')

# %%
df
# Out:
#        Area Policiaca Delito        Delitos_code       Fecha      Hora  \
# 0            Aibonito      6  Apropiacion Ilegal  2013/04/07   8:30:00
# 1            Aibonito      7    Vehiculo Hurtado  2013/06/06   1:00:00
# 2            Aibonito      6  Apropiacion Ilegal  2013/05/14  13:00:00
# 3            Aibonito      5        Escalamiento  2013/04/14  13:30:00
# 4            Aibonito      7    Vehiculo Hurtado  2013/04/21  21:00:00
# 5            Aibonito      5        Escalamiento  2013/06/27  17:30:00
# 6            Aibonito      5        Escalamiento  2013/06/30  19:00:00
# 7            Aibonito      6  Apropiacion Ilegal  2013/01/11  13:45:00
# 8            Aibonito      6  Apropiacion Ilegal  2013/01/26  11:30:00
# 9            Aibonito      6  Apropiacion Ilegal  2013/02/13  16:00:00
# 10           Aibonito      5        Escalamiento  2013/03/10  10:35:00
# 11           Aibonito      5        Escalamiento  2013/01/13  13:00:00
# ...

# %%
query = ''
x = sqldf(query)
